# %% [markdown]
# # Afterclass clase 8

# %% [markdown]
# #### grabar la clase

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pd.read_csv?

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'tips',
#  'titanic']

# %% [markdown]
# # Vamos a trabajar con el set de datos de titanic

# %%
df_titanic = sns.load_dataset('titanic')

# %%
df_titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# # Estadística básica

# %%
df_describe_titanic = df_titanic.describe(include='all').round(1)
df_describe_titanic
# Out:
#         survived  pclass   sex    age  sibsp  parch   fare embarked  class  \
# count      891.0   891.0   891  714.0  891.0  891.0  891.0      889    891
# unique       NaN     NaN     2    NaN    NaN    NaN    NaN        3      3
# top          NaN     NaN  male    NaN    NaN    NaN    NaN        S  Third
# freq         NaN     NaN   577    NaN    NaN    NaN    NaN      644    491
# mean         0.4     2.3   NaN   29.7    0.5    0.4   32.2      NaN    NaN
# std          0.5     0.8   NaN   14.5    1.1    0.8   49.7      NaN    NaN
# min          0.0     1.0   NaN    0.4    0.0    0.0    0.0      NaN    NaN
# 25%          0.0     2.0   NaN   20.1    0.0    0.0    7.9      NaN    NaN
# 50%          0.0     3.0   NaN   28.0    0.0    0.0   14.5      NaN    NaN
# 75%          1.0     3.0   NaN   38.0    1.0    0.0   31.0      NaN    NaN
# max          1.0     3.0   NaN   80.0    8.0    6.0  512.3      NaN    NaN
#
#         who adult_male deck  embark_town alive alone
# ...

# %%
df_titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.6+ KB

# %%
df_titanic.std(axis='rows')
# Out:
# survived       0.486592
# pclass         0.836071
# age           14.526497
# sibsp          1.102743
# parch          0.806057
# fare          49.693429
# adult_male     0.489615
# alone          0.489615
# dtype: float64

# %% [markdown]
# # Contando los valores nulos

# %%
df_titanic.isna().sum(axis='rows')
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# # seleccion de subgrupos

# %%
df_titanic['mibooltest'] = df_titanic['sex']=='female'

# %%
df_titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
# consideramos solo mujeres
df_titanic_female = df_titanic.loc[df_titanic['sex']=='female']
df_titanic_female
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
#
# ...

# %%
# consideramos solo primera clase
df_titanic_1 = df_titanic.loc[((df_titanic['pclass']==1) | 
                               (df_titanic['sex']=='female')) & 
                              ((df_titanic['embark_town']=='Cherbourg')),
                             ]
df_titanic_1
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 1           1       1  female  38.0      1      0   71.2833        C   First
# 9           1       2  female  14.0      1      0   30.0708        C  Second
# 19          1       3  female   NaN      0      0    7.2250        C   Third
# 30          0       1    male  40.0      0      0   27.7208        C   First
# 31          1       1  female   NaN      1      0  146.5208        C   First
# ..        ...     ...     ...   ...    ...    ...       ...      ...     ...
# 866         1       2  female  27.0      1      0   13.8583        C  Second
# 874         1       2  female  28.0      1      0   24.0000        C  Second
# 875         1       3  female  15.0      0      0    7.2250        C   Third
# 879         1       1  female  56.0      0      1   83.1583        C   First
# 889         1       1    male  26.0      0      0   30.0000        C   First
#
# ...

# %%
df_titanic_1.loc[19]
# Out:
# survived               1
# pclass                 3
# sex               female
# age                  NaN
# sibsp                  0
# parch                  0
# fare               7.225
# embarked               C
# class              Third
# who                woman
# adult_male         False
# deck                 NaN
# embark_town    Cherbourg
# alive                yes
# alone               True
# mibooltest          True
# Name: 19, dtype: object

# %%
# Cuantas mujeres embarcaron por cada puerta 
df_titanic_female['embarked'].value_counts()
# Out:
# S    203
# C     73
# Q     36
# Name: embarked, dtype: int64

# %%
df_titanic['embark_town'].value_counts()
# Out:
# Southampton    644
# Cherbourg      168
# Queenstown      77
# Name: embark_town, dtype: int64

# %%
df_titanic[df_titanic['embark_town'].str.contains('n',na=False)]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# 5           0       3    male   NaN      0      0   8.4583        Q   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %% [markdown]
# # Seaborn

# %%
ax = sns.countplot(data=df_titanic, x='class',  hue='who',)
ax.set(xlabel='Clase', ylabel='Numero de personas', title='');

# %%
g = sns.catplot(x="class", hue="who", col="alive",
                data=df_titanic, kind="count",
                height=4, aspect=.7);

# %%
ax = sns.catplot(data=df_titanic, kind='violin', x='pclass', y='age', hue = 'alive',split = True )
ax.set(xlabel='Clase', ylabel='Distribución de edades', title='Categorización de la distribución de pulsaciones')

# %%
clarity_ranking = ["I1", "SI2", "SI1", "VVS2", "VVS1", "IF" "VS2", "VS1"]  

sns.boxenplot(x="pclass", y="age",  
              color="g", 
              scale="linear", data=df_titanic)

# %%
ax = sns.displot(data=df_titanic, x='age', kind='hist', hue='alive', fill=True)
