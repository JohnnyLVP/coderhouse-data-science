# %%
import numpy as np

# %% [markdown]
# #Datos importantes:
#
# Numpy es una librería muy importante para Python ya que es la base de todos los cálculos científicos y muchas de las librerías de Machine Learning.
#
# Scikit-Learn con sus modelos, cuando retorna un resultado, en general lo retorna en un formato Numpy.
#
# Las listas no poseen métodos prácticos para hacer aritmética.
#
# Es importante saber que otros lenguajes de programación poseen librerías altamente optimizadas para hacer cálculos numéricos con vectores de datos. Numpy es esa librería para el lenguaje de programación de Python.

# %% [markdown]
# ![imagen.png](attachment:imagen.png)

# %%
#Pq es importante el seed?
seed=np.random.seed(42)
array = np.random.randint(0,1000,size=5)
array
# Out:
# array([102, 435, 860, 270, 106])

# %%
seed=np.random.seed(42)
array = np.random.randint(0,1000,size=5)
array
# Out:
# array([102, 435, 860, 270, 106])

# %% [markdown]
# ![imagen.png](attachment:imagen.png)

# %%
seed=np.random.seed(42)
array = np.random.randint(0,1000,size=100)
array
# Out:
# array([102, 435, 860, 270, 106,  71, 700,  20, 614, 121, 466, 214, 330,
#        458,  87, 372,  99, 871, 663, 130, 661, 308, 769, 343, 491, 413,
#        805, 385, 191, 955, 276, 160, 459, 313,  21, 252, 747, 856, 560,
#        474,  58, 510, 681, 475, 699, 975, 782, 189, 957, 686, 957, 562,
#        875, 566, 243, 831, 504, 130, 484, 818, 646,  20, 840, 166, 273,
#        387, 600, 315,  13, 241, 776, 345, 564, 897, 339,  91, 366, 955,
#        454, 427, 508, 775, 942,  34, 205,  80, 931, 561, 871, 387,   1,
#        389, 565, 105, 771, 821, 476, 702, 401, 729])

# %%
array_sorted = np.sort(array) #asi se ordena un array

# %%
print(array,"\n\n\n", array_sorted)
# Out:
# [102 435 860 270 106  71 700  20 614 121 466 214 330 458  87 372  99 871
#  663 130 661 308 769 343 491 413 805 385 191 955 276 160 459 313  21 252
#  747 856 560 474  58 510 681 475 699 975 782 189 957 686 957 562 875 566
#  243 831 504 130 484 818 646  20 840 166 273 387 600 315  13 241 776 345
#  564 897 339  91 366 955 454 427 508 775 942  34 205  80 931 561 871 387
#    1 389 565 105 771 821 476 702 401 729]
#
#
#  [  1  13  20  20  21  34  58  71  80  87  91  99 102 105 106 121 130 130
#  160 166 189 191 205 214 241 243 252 270 273 276 308 313 315 330 339 343
#  345 366 372 385 387 387 389 401 413 427 435 454 458 459 466 474 475 476
#  484 491 504 508 510 560 561 562 564 565 566 600 614 646 661 663 681 686
#  699 700 702 729 747 769 771 775 776 782 805 818 821 831 840 856 860 871
#  871 875 897 931 942 955 955 957 957 975]

# %%
array_sorted[49] #MEDIANA -> ¿ESTAN SEGUROS/AS QUE ESTA BIEN?
# Out:
# 459

# %%
array_sorted[100]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-180-5a6fb29d1002> in <module>
# ----> 1 array_sorted[100]
#
# IndexError: index 100 is out of bounds for axis 0 with size 100

# %%
def factorial(x): #FUNCION ANTERIOR, prestar atencion al range
    fac = 1
    for i in range(1, x):
        fac *= i + 1
    return fac
factorial(5)
# Out:
# 120

# %%
len("-----")
# Out:
# 5

# %%
def factorial(x): #FUNCION 2.0
    fac = 1
    for i in range(1,arra[-1])): #aqui cambia
        fac *= i + 1
    return fac
factorial(array_sorted)
# Out:
# 93326215443944152681699238856266700490715968264381621468592963895217599993229915608941463976156518286253697920827223758251185210916864000000000000000000000000

# %%
def sumatoria(x, y): #Funcion anterior
    suma = 0
    for i in range(x, y+1):
        suma += i
    return suma
sumatoria(1,975)
# Out:
# 475800

# %%
def sumatoria_v2(array):
    suma = 0
    x = array[0]
    y = array[-1]
    print(x,"\n",y)
    for i in range(x, y+1):
        suma += i
    return suma

sumatoria_v2(array_sorted)
# Out:
# 1
#  975
# 475800

# %%
sum(array) #aburrido
# Out:
# 47379

# %%
pwd
# Out:
# 'C:\\Users\\fvegamaza\\111'

# %%
import pandas as pd

# %%
data = pd.read_csv("C:/Users/fvegamaza/111/Salarios Openqube_v2.csv")
data.head()
# Out:
#            Timestamp Me identifico  Tengo Estoy trabajando en  \
# 0   7/6/2020 9:56:02         Mujer     26           Argentina
# 1   7/6/2020 9:57:09        Hombre     29           Argentina
# 2   7/6/2020 9:58:09         Mujer     22           Argentina
# 3   7/6/2020 9:59:52        Hombre     39           Argentina
# 4  7/6/2020 10:01:27        Hombre     32           Argentina
#
#             D�nde est�s trabajando Bolivia Chile Colombia Cuba Costa Rica  \
# 0  Ciudad Aut�noma de Buenos Aires     NaN   NaN      NaN  NaN        NaN
# 1                       Corrientes     NaN   NaN      NaN  NaN        NaN
# 2  Ciudad Aut�noma de Buenos Aires     NaN   NaN      NaN  NaN        NaN
# 3                       Corrientes     NaN   NaN      NaN  NaN        NaN
# 4  Ciudad Aut�noma de Buenos Aires     NaN   NaN      NaN  NaN        NaN
#
#    ... �Con cu�ntas personas est�s conviviendo?  \
# 0  ...                                        0
# ...

# %%
salarios_brutos = data["Salario mensual BRUTO (en tu moneda local)"].copy(deep=True)
salarios_brutos
# Out:
# 0        53000
# 1        79000
# 2       160000
# 3       130000
# 4       140000
#          ...
# 6410     99000
# 6411     85000
# 6412     47250
# 6413     86000
# 6414     85000
# Name: Salario mensual BRUTO (en tu moneda local), Length: 6415, dtype: object

# %%
salarios_brutos = salarios_brutos.to_numpy() #ahora es un array :D

# %%
salarios_brutos[100:800]
# Out:
# array(['124000', '54000', '35929', '150000', '41000', '33000', '84762',
#        '80000', '17000', '110000', '49000', '130000', '52452', '56000',
#        '45000', '74000', '90000', '101500', '145000', '83000', '151000',
#        '58000', '350000', '134000', '123000', '77000', '120000', '180000',
#        '120000', '40000', '350000', '45000', '80000', '60000', '85000',
#        '62246', '80500', '200000', '57634', '121700', '150000', '200000',
#        '60000', '120000', '50000', '110000', '78000', '58000', '280000',
#        '119000', '58000', '67000', '65000', '55', '45000', '230000',
#        '33000', '100000', '90000', '36000', '6300', '200000', '64000',
#        '77000', '99000', '85000', '110000', '124000', '75', '108000',
#        '107000', '84000', '50000', '50000', '168000', '43000', '52600',
#        '90000', '57000', '130000', '76000', '134000', '185000', '140000',
#        '56000', '100000', '48000', '27500', '166500', '110000', '180000',
# ...

# %%
salarios_brutos.sum()
# Out:
# '........29000011000010500023400060000820008400012500090000125000125000195000400009638512200066214700001550009600018790000500037500357077000042981.251650009900065000280000120000150000720001500004044018000010000011000021,329230200020000180000300001000009090000242000222000730001200005640010800043000230000930004500012100018000012500080000050225.43830008300047000405000420000300005000051000360005200039300400002180039.....26620057000130000140000265558.7272007.42345311240001700001300001600008606815800010000053000500001100008000072300660001850006600036501.9660325.........96153800140000140000128700145000500006000079200073000840003500011100075000799993500020000092000152200120000146000608405180012849070000800009099825600008845044,907115200350003500006100050657309512000020000450001490001100001590001000006000080000950001450006700050000137000350005840015000078900100001500002100004165001160003000001523002300008806081,78364007000023500011000048,3597500014500030803143000144830110000900002840004000011
# ...

# %%
salarios_brutos.mean() #esto pasa porque no puedo sacar la media de valores string
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-173-3ea934db8a5f> in <module>
# ----> 1 salarios_brutos.mean()
#
# c:\users\fvegamaza\miniconda3\envs\env2\lib\site-packages\numpy\core\_methods.py in _mean(a, axis, dtype, out, keepdims)
#     170             ret = ret.dtype.type(ret / rcount)
#     171     else:
# --> 172         ret = ret / rcount
#     173
#     174     return ret
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
salarios_brutos = data["Salario mensual BRUTO (en tu moneda local)"].copy(deep=True).astype(float) 
#lo intento pasar a flotante, me da error porque no sabe como interpretar la coma
#recorda q en eeuu los miles se separan con punto
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-138-90eddcf19d96> in <module>
# ----> 1 salarios_brutos = data["Salario mensual BRUTO (en tu moneda local)"].copy(deep=True).astype(float)
#
# c:\users\fvegamaza\miniconda3\envs\env2\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5875         else:
#    5876             # else, only a single dtype is given
# -> 5877             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5878             return self._constructor(new_data).__finalize__(self, method="astype")
#    5879
#
# c:\users\fvegamaza\miniconda3\envs\env2\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     629         self, dtype, copy: bool = False, errors: str = "raise"
#     630     ) -> "BlockManager":
# ...

# %%
salarios_brutos = data["Salario mensual BRUTO (en tu moneda local)"].copy(deep=True).str.replace(',', '').astype(float)
#cambio la coma por nada, es decir donde antes habia 21,329 va a quedar 21329
salarios_brutos
# Out:
# 0        53000.0
# 1        79000.0
# 2       160000.0
# 3       130000.0
# 4       140000.0
#           ...
# 6410     99000.0
# 6411     85000.0
# 6412     47250.0
# 6413     86000.0
# 6414     85000.0
# Name: Salario mensual BRUTO (en tu moneda local), Length: 6415, dtype: float64

# %%
salarios_brutos.sum()
# Out:
# 19194584083996.395

# %%
salarios_brutos.mean()
# Out:
# 2992140932.8131557

# %%
salarios_brutos.max()
# Out:
# 19192900000000.0

# %%
salarios_brutos.min()
# Out:
# 1.0

# %%
np.median(salarios_brutos)
# Out:
# 95000.0

# %%
np.std(salarios_brutos)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-193-72449fd949f3> in <module>
# ----> 1 np.std(salarios_brutos)
#
# <__array_function__ internals> in std(*args, **kwargs)
#
# c:\users\fvegamaza\miniconda3\envs\env2\lib\site-packages\numpy\core\fromnumeric.py in std(a, axis, dtype, out, ddof, keepdims)
#    3494             return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
#    3495
# -> 3496     return _methods._std(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
#    3497                          **kwargs)
#    3498
#
# c:\users\fvegamaza\miniconda3\envs\env2\lib\site-packages\numpy\core\_methods.py in _std(a, axis, dtype, out, ddof, keepdims)
#     231
#     232 def _std(a, axis=None, dtype=None, out=None, ddof=0, keepdims=False):
# --> 233     ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
#     234                keepdims=keepdims)
# ...

# %%
salarios_brutos.dtype
# Out:
# dtype('float64')

# %%
import pandas as pd
sheet_url = "https://docs.google.com/spreadsheets/d/15Stnum8mI9QdwF9ZiPFCe3_qG9XyZyNzmOSIDunzPjA/view#gid=255849258"
url = sheet_url.replace("/view#gid=", "/export?format=csv&gid=")
df = pd.read_csv(url)

# %%
df
# Out:
#                Timestamp Me identifico  Tengo Estoy trabajando en  \
# 0       7/6/2020 9:56:02         Mujer     26           Argentina
# 1       7/6/2020 9:57:09        Hombre     29           Argentina
# 2       7/6/2020 9:58:09         Mujer     22           Argentina
# 3       7/6/2020 9:59:52        Hombre     39           Argentina
# 4      7/6/2020 10:01:27        Hombre     32           Argentina
# ...                  ...           ...    ...                 ...
# 6410  8/15/2020 22:04:58        Hombre     37           Argentina
# 6411  8/15/2020 22:48:40        Hombre     38           Argentina
# 6412  8/15/2020 23:54:10        Hombre     24           Argentina
# 6413   8/16/2020 0:45:57        Hombre     28           Argentina
# 6414   8/16/2020 1:03:20        Hombre     33           Argentina
#
#                Dónde estás trabajando Bolivia Chile Colombia Cuba Costa Rica  \
# 0     Ciudad Autónoma de Buenos Aires     NaN   NaN      NaN  NaN        NaN
# ...
